# %% [markdown]
# <a href="https://colab.research.google.com/github/gangisettisaibabu132625-hash/DAA-LAB/blob/main/DAA_PRACTICAL_2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time

# Input from the user
n = int(input("Enter the number of elements: "))

arr = []
print(f"Enter {n} sorted elements:")
for i in range(n):
    arr.append(int(input()))

# Element to search
key = int(input("Enter the element to search: "))

# Start timer
start_time = time.time()

# Linear Search
position = -1
for i in range(n):
    if arr[i] == key:
        position = i
        break

# Stop timer
end_time = time.time()

# Calculate execution time
execution_time = end_time - start_time

# Display result
if position != -1:
    print(f"\nElement {key} found at index {position}")
else:
    print(f"\nElement {key} not found")

# Display execution time
print(f"\nExecution Time: {execution_time:.6f} seconds")

# Display time complexity
print("\nTime Complexity:")
print("Best Case    : O(1)")
print("Average Case : O(n)")
print("Worst Case   : O(n)")
print("Space Complexity: O(1)")
# Out:
# Enter the number of elements: 4
# Enter 4 sorted elements:
# 2
# 3
# 5
# 6
# Enter the element to search: 5
#
# Element 5 found at index 2
#
# Execution Time: 0.000168 seconds
#
# Time Complexity:
# Best Case    : O(1)
# Average Case : O(n)
# Worst Case   : O(n)
# Space Complexity: O(1)
